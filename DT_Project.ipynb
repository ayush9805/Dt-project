# %%
import pandas as  pd
import numpy as np
pd.read_csv('insurance_claims.csv')
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
insurancefraud = pd.read_csv('insurance_claims.csv')

# %%
insurancefraud
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.classification import *
s = setup(data = insurancefraud,target ='fraud_reported' )
# Out:
# <style type="text/css">
# #T_0abb5_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0abb5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0abb5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0abb5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0abb5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0abb5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0abb5_row0_col1" class="data row0 col1" >8602</td>
#     </tr>
#     <tr>
#       <th id="T_0abb5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0abb5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0abb5_row1_col1" class="data row1 col1" >fraud_reported</td>
#     </tr>
#     <tr>
#       <th id="T_0abb5_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm = compare_models()
# Out:
# <style type="text/css">
# #T_4a855 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# **Model performance using  data normalization**

# %%
s = setup(data = insurancefraud, target = 'fraud_reported', normalize = True, normalize_method = 'zscore')
cm = compare_models()
# Out:
# <style type="text/css">
# #T_b282f_row12_col1, #T_b282f_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b282f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b282f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b282f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b282f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b282f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b282f_row0_col1" class="data row0 col1" >4037</td>
#     </tr>
#     <tr>
#       <th id="T_b282f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b282f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b282f_row1_col1" class="data row1 col1" >fraud_reported</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Model Performance using feature selection**

# %%
s = setup(data=insurancefraud, target='fraud_reported', feature_selection = True)
cm = compare_models()
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 173, number of negative: 527
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000220 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2502
# [LightGBM] [Info] Number of data points in the train set: 700, number of used features: 125
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.247143 -> initscore=-1.113909
# [LightGBM] [Info] Start training from score -1.113909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# **Model performance using outliers removal**

# %%
s = setup(data=insurancefraud, target='fraud_reported', remove_outliers = True, outliers_threshold = 0.05)
cm = compare_models()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# <style type="text/css">
# #T_1eb86_row12_col1, #T_1eb86_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1eb86" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1eb86_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1eb86_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1eb86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1eb86_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# **Model performance using PCA method**

# %%
s = setup(data=insurancefraud, target='fraud_reported', pca = True, pca_method = 'linear')
cm = compare_models()
# Out:
# <style type="text/css">
# #T_9bfdd_row12_col1, #T_9bfdd_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9bfdd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bfdd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9bfdd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bfdd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bfdd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9bfdd_row0_col1" class="data row0 col1" >6965</td>
#     </tr>
#     <tr>
#       <th id="T_9bfdd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bfdd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9bfdd_row1_col1" class="data row1 col1" >fraud_reported</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Model performance using outlier removal  and normalization**

# %%
s = setup(data=insurancefraud, target='fraud_reported', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore')
cm = compare_models()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# <style type="text/css">
# #T_2bdbb_row12_col1, #T_2bdbb_row18_col1, #T_2bdbb_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2bdbb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bdbb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2bdbb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bdbb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bdbb_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# **RF MODEL**

# %%
from pycaret.classification import *

s = setup(data=insurancefraud, target='fraud_reported')
rfModel = create_model('rf')
# Out:
# <style type="text/css">
# #T_c33aa_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c33aa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c33aa_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c33aa_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c33aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c33aa_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c33aa_row0_col1" class="data row0 col1" >5201</td>
#     </tr>
#     <tr>
#       <th id="T_c33aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c33aa_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c33aa_row1_col1" class="data row1 col1" >fraud_reported</td>
#     </tr>
#     <tr>
#       <th id="T_c33aa_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
plot_model(rfModel, plot='confusion_matrix')

# %%
plot_model(rfModel)

# %% [markdown]
# **lr model**

# %%
from pycaret.classification import *

s = setup(data=insurancefraud, target='fraud_reported')
lrModel = create_model('lr')
# Out:
# <style type="text/css">
# #T_f80c1_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f80c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f80c1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f80c1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f80c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f80c1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f80c1_row0_col1" class="data row0 col1" >4101</td>
#     </tr>
#     <tr>
#       <th id="T_f80c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f80c1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f80c1_row1_col1" class="data row1 col1" >fraud_reported</td>
#     </tr>
#     <tr>
#       <th id="T_f80c1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
plot_model(lrModel, plot='confusion_matrix')

# %% [markdown]
# **Ridge model**

# %%
from pycaret.classification import *

s = setup(data=insurancefraud, target='fraud_reported',remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore',feature_selection = True)
ridgeModel = create_model('ridge')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 158, number of negative: 507
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000960 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2480
# [LightGBM] [Info] Number of data points in the train set: 665, number of used features: 125
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.237594 -> initscore=-1.165916
# [LightGBM] [Info] Start training from score -1.165916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
plot_model(ridgeModel, plot='confusion_matrix')

# %% [markdown]
# **Nb Model**

# %%
from pycaret.classification import *

s = setup(data=insurancefraud, target='fraud_reported')
nbModel = create_model('nb')
# Out:
# <style type="text/css">
# #T_d6bad_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d6bad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6bad_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d6bad_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6bad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6bad_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d6bad_row0_col1" class="data row0 col1" >1600</td>
#     </tr>
#     <tr>
#       <th id="T_d6bad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6bad_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d6bad_row1_col1" class="data row1 col1" >fraud_reported</td>
#     </tr>
#     <tr>
#       <th id="T_d6bad_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
plot_model(nbModel, plot='confusion_matrix')

# %%
plot_model(nbModel)

# %% [markdown]
# **ET Model**

# %%
from pycaret.classification import *

s = setup(data=insurancefraud, target='fraud_reported')
etModel = create_model('et')
# Out:
# <style type="text/css">
# #T_f16a4_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f16a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f16a4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f16a4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f16a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f16a4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f16a4_row0_col1" class="data row0 col1" >3778</td>
#     </tr>
#     <tr>
#       <th id="T_f16a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f16a4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f16a4_row1_col1" class="data row1 col1" >fraud_reported</td>
#     </tr>
#     <tr>
#       <th id="T_f16a4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
plot_model(etModel, plot='confusion_matrix')

# %%
plot_model(etModel)

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/insurance_claims.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
insurancefraudDataset = pd.read_csv('/content/drive/MyDrive/dataset/insurance_claims.csv')

# %%
insurancefraudDataset
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
## Scatter plot
import matplotlib.pyplot as plt

x = insurancefraudDataset['months_as_customer']
y = insurancefraudDataset['policy_annual_premium']

plt.xlabel('months_as_customer')
plt.ylabel('policy_annual_premium')


plt.scatter(x, y, marker = "+",color = "blue")

plt.show()

# %%
import matplotlib.pyplot as plt

idxes = insurancefraudDataset['total_claim_amount']
arr1  = insurancefraudDataset['vehicle_claim']
arr2  = insurancefraudDataset['injury_claim']
arr3  = insurancefraudDataset['policy_annual_premium']

# Adding legend for stack plots is tricky.
plt.plot([], [], color='r', label = 'D 1')
plt.plot([], [], color='g', label = 'D 2')
plt.plot([], [], color='b', label = 'D 3')

plt.stackplot(idxes, arr1, arr2,arr3,colors= ['r', 'g','b'])
plt.title('Stack Plot Example')
plt.legend()
plt.show()

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

data = [
    go.Contour(
        z=[['total_claim_amount'],
           ['property_claim'],
           ['injury_claim'],
           ['vehicle_claim']]
    )
]
iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = insurancefraudDataset['injury_claim']
y = insurancefraudDataset['property_claim']
z = insurancefraudDataset['vehicle_claim']


ax.scatter(x, y, z, c='purple', marker='o', label='purple')


ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
plt.title("3D Scatter Plot Example")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Look at index 4 and 6, which demonstrate overlapping cases.
x1 = insurancefraudDataset['policy_number']
y1 = insurancefraudDataset['policy_annual_premium']



# Colors: https://matplotlib.org/api/colors_api.html

plt.bar(x, y, label="green Bar", color='g')

plt.plot()

plt.xlabel("policy number")
plt.ylabel("policy premium")
plt.title("Bar Chart Example")
plt.legend()
plt.show()

# %%
insurancefraudDataset=df.head(30)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
x = insurancefraudDataset['months_as_customer']
y = insurancefraudDataset['fraud_reported']

plt.plot(x, y)
plt.savefig("testImage2.jpg", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,5))
x = insurancefraudDataset['months_as_customer']
y = insurancefraudDataset['fraud_reported']

plt.plot(x, y)
plt.savefig("testImage2.jpg", dpi=300)
plt.show()
